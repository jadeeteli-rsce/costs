# %% [markdown]
# imports and parsing through

# %%
import pandas as pd
import glob
from IPython.display import display

pd.set_option("display.max_columns", None)
pd.set_option("display.max_colwidth", None)

files = sorted(glob.glob("data/**/*.xlsx", recursive=True))
print(f"Found {len(files)} files:\n")
for f in files:
    print(f)
# Out:
# Found 21 files:
#
# data/2018/2018 TARIFAS Y COLABORADORAS CON Y SIN IVA.xlsx
# data/2019/2019 TARIFA COLABORADORAS v1.xlsx
# data/2019/2019 TARIFA USUARIOS Y SOCIOS v2.xlsx
# data/2020/2020 IMPRESO CANINAS V2020.xlsx
# data/2020/2020_TARIFAS.xlsx
# data/2021/2021 ESTUDIO MODIFICACION TARIFAS (NO HAY MÁS).xlsx
# data/2021/2021_TARIFAS.xlsx
# data/2022/2022 IMPRESO COLABORADORAS V2022_3.xlsx
# data/2022/2022_TARIFAS_V1_1_Ago.xlsx
# data/2022/2022_TARIFAS_V1_Feb.xlsx
# data/2022/2022_TARIFAS_V3_Oct.xlsx
# data/2023/2023 IMPRESO COLABORADORAS V2023_1.xlsx
# data/2023/2023_TARIFAS.xlsx
# data/2024/2024 IMPRESO COLABORADORAS V3.xlsx
# data/2024/2024_TARIFAS.xlsx
# data/2025/2025 IMPRESO COLABORADORAS v2.xlsx
# data/2025/2025 IMPRESO COLABORADORAS v4.xlsx
# data/2025/2025_TARIFAS_V3_Ene.xlsx
# data/2025/2025_TARIFAS_V4_Sept.xlsx
# data/2026/2026 IMPRESO COLABORADORAS v3.xlsx
# data/2026/2026 TARIFAS V2.xlsx

# %% [markdown]
# 2018

# %%
df = pd.read_excel("data/2018/2018 TARIFAS Y COLABORADORAS CON Y SIN IVA.xlsx", header=None)
df.head(15)
# Out:
#                                                                                                          0   \
# 0                                                                                                      2018
# 1                                                                                                       NaN
# 2                                                                                                       NaN
# 3                                                                                                       NaN
# 4                                                                   PEDIGREES Y TRANSFERENCIAS DE PROPIEDAD
# 5                                                              PEDIGREE CON TRANSFERENCIA TRES GENERACIONES
# 6   PEDIGREE CON TRANSFERENCIA CUATRO GENERACIONES (si la genealogía consta en la base de datos del L.O.E.)
# 7                                    PEDIGREE PARA PERROS INSCRITOS EN EL R.R.C. (sin genealógica completa)
# ...

# %%
df = pd.read_excel("data/2018/2018 IMPRESO CANINAS.xlsm", header=None)
df.head(10)
# Out:
#                                         0  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4  PEDIGREES Y TRANSFERENCIA DE PROPIEDAD
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
#
#                                                                            1  \
# 0                                                           SOCIEDAD CANINA
# 1                                                                      FECHA
# 2                                                                        NaN
# 3                                                                   CONCEPTO
# 4                                                                        NaN
# ...

# %% [markdown]
# 2019

# %%
df = pd.read_excel("data/2019/2019 TARIFA COLABORADORAS v1.xlsx", header=None)
df.head(10)
# Out:
#                                                                            0  \
# 0                                                           SOCIEDAD CANINA
# 1                                                                      FECHA
# 2                                                                        NaN
# 3                                                                   CONCEPTO
# 4                                     PEDIGREES Y TRANSFERENCIA DE PROPIEDAD
# 5                               PEDIGREE CON TRANSFERENCIA TRES GENERACIONES
# 6  PEDIGREE CON TRANSFERENCIA CUATRO GENERACIONES  (si consta en el L.O.E..)
# 7      PEDIGREE PARA PERROS INSCRITOS EN EL R.R.C. (sin genealogía completa)
# 8                                   PEDIGREE DE EXPORTACION (3 generaciones)
# 9                                   PEDIGREE DE EXPORTACION (4 generaciones)
#
#     1    2       3         4       5    6        7
# 0 NaN  NaN     NaN       NaN     NaN  NaN      NaN
# ...

# %%
df = pd.read_excel("data/2019/2019 TARIFA USUARIOS Y SOCIOS v2.xlsx")
df.head(15)
# Out:
#                                                                                                    Unnamed: 0  \
# 0                                                                                                         NaN
# 1                                                                                                         NaN
# 2                                                                                                         NaN
# 3                                                                                                         NaN
# 4                                                                                                         NaN
# 5                                                                                   TARIFA GENERAL DE PRECIOS
# 6                                                              (en vigor a partir del día 1 de enero de 2019)
# ...

# %% [markdown]
# 2020

# %%
df = pd.read_excel("data/2020/2020 IMPRESO CANINAS V2020.xlsx")
df.head(15)
# Out:
#                                                              SOCIEDAD CANINA   \
# 0                                                                       FECHA
# 1                                                                         NaN
# 2                                                                    CONCEPTO
# 3                                      PEDIGREES Y TRANSFERENCIA DE PROPIEDAD
# 4                                PEDIGREE CON TRANSFERENCIA TRES GENERACIONES
# 5   PEDIGREE CON TRANSFERENCIA CUATRO GENERACIONES  (SI CONSTAN EN EL L.O.E.)
# 6       PEDIGREE PARA PERROS INSCRITOS EN EL R.R.C. (SIN GENEALOGIA COMPLETA)
# 7                                    PEDIGREE DE EXPORTACION (3 generaciones)
# 8                                    PEDIGREE DE EXPORTACION (4 generaciones)
# 9                                                  PEDIGREE SIN TRANSFERENCIA
# 10  PEDIGREE SIN TRANSFERENCIA CUATRO GENERACIONES  (SI CONSTAN EN EL L.O.E.)
# ...

# %%
df = pd.read_excel("data/2020/2020_TARIFAS.xlsx")
df.head(15)
# Out:
#                                   Categoría  \
# 0   PEDIGREES Y TRANSFERENCIAS DE PROPIEDAD
# 1   PEDIGREES Y TRANSFERENCIAS DE PROPIEDAD
# 2   PEDIGREES Y TRANSFERENCIAS DE PROPIEDAD
# 3   PEDIGREES Y TRANSFERENCIAS DE PROPIEDAD
# 4   PEDIGREES Y TRANSFERENCIAS DE PROPIEDAD
# 5   PEDIGREES Y TRANSFERENCIAS DE PROPIEDAD
# 6   PEDIGREES Y TRANSFERENCIAS DE PROPIEDAD
# 7   PEDIGREES Y TRANSFERENCIAS DE PROPIEDAD
# 8   PEDIGREES Y TRANSFERENCIAS DE PROPIEDAD
# 9   PEDIGREES Y TRANSFERENCIAS DE PROPIEDAD
# 10  PEDIGREES Y TRANSFERENCIAS DE PROPIEDAD
# 11  PEDIGREES Y TRANSFERENCIAS DE PROPIEDAD
# 12  PEDIGREES Y TRANSFERENCIAS DE PROPIEDAD
# 13            INSCRIPCIONES EN EL LOE / RRC
# 14            INSCRIPCIONES EN EL LOE / RRC
#
#                                                                                                  Trámite  \
# 0                                                           PEDIGREE CON TRANSFERENCIA TRES GENERACIONES
# ...

# %%
df = pd.read_excel("data/2021/2021 ESTUDIO MODIFICACION TARIFAS (NO HAY MÁS).xlsx")
df.head(15)
# Out:
#                                                                                                  Unnamed: 0  \
# 0                                                                                                       NaN
# 1                                                                   PEDIGREES Y TRANSFERENCIAS DE PROPIEDAD
# 2                                                              PEDIGREE CON TRANSFERENCIA TRES GENERACIONES
# 3   PEDIGREE CON TRANSFERENCIA CUATRO GENERACIONES (si la genealogía consta en la base de datos del L.O.E.)
# 4                                    PEDIGREE PARA PERROS INSCRITOS EN EL R.R.C. (sin genealógica completa)
# 5                                                                 PEDIGREE DE EXPORTACIÓN TRES GENERACIONES
# 6      PEDIGREE DE EXPORTACIÓN CUATRO GENERACIONES (si la genealogía consta en la base de datos del L.O.E.)
# 7                                                                                PEDIGREE SIN TRANSFERENCIA
# ...

# %%
df = pd.read_excel("data/2021/2021_TARIFAS.xlsx")
df.head(15)
# Out:
#                                   Categoría  \
# 0                             INSCRIPCIONES
# 1                             INSCRIPCIONES
# 2                             INSCRIPCIONES
# 3                             INSCRIPCIONES
# 4                             INSCRIPCIONES
# 5                             INSCRIPCIONES
# 6                             INSCRIPCIONES
# 7                             INSCRIPCIONES
# 8                             INSCRIPCIONES
# 9                             INSCRIPCIONES
# 10                            INSCRIPCIONES
# 11                            INSCRIPCIONES
# 12                            INSCRIPCIONES
# 13                            INSCRIPCIONES
# 14  PEDIGRÍES Y TRANSFERENCIAS DE PROPIEDAD
#
#                                                                                                         Trámite  \
# 0                                                                                      REGISTRO INICIAL DE RAZA
# ...

# %% [markdown]
# 2022

# %%
df = pd.read_excel("data/2022/2022 IMPRESO COLABORADORAS V2022_3.xlsx")
df.head(15)
# Out:
#                                                                              SOCIEDAD CANINA   \
# 0                                                                                       FECHA
# 1                                                                                         NaN
# 2                                                                                    CONCEPTO
# 3                                                            INCRIPCIONES EN EL L.O.E./R.R.C.
# 4                                                         REGISTRO INICIAL DE RAZAS ESPAÑOLAS
# 5                                                         REGISTRO INICIAL DEL RESTO DE RAZAS
# 6                                                                      IMPRESO ALTA DE CAMADA
# 7                       FORMULARIO IDENTIFICACION (por cachorro al notificar nacimiento) RSCE
# 8                  FORMULARIO IDENTIFICACION (por cachorro al notificar nacimiento) EN ORIGEN
# ...

# %%
df = pd.read_excel("data/2022/2022_TARIFAS_V1_1_Ago.xlsx")
df.head(15)
# Out:
#         Categoría  \
# 0   INSCRIPCIONES
# 1   INSCRIPCIONES
# 2   INSCRIPCIONES
# 3   INSCRIPCIONES
# 4   INSCRIPCIONES
# 5   INSCRIPCIONES
# 6   INSCRIPCIONES
# 7   INSCRIPCIONES
# 8   INSCRIPCIONES
# 9   INSCRIPCIONES
# 10  INSCRIPCIONES
# 11  INSCRIPCIONES
# 12  INSCRIPCIONES
# 13  INSCRIPCIONES
# 14  INSCRIPCIONES
#
#                                                                                                         Trámite  \
# 0                                                                              REGISTRO INICIAL RAZAS ESPAÑOLAS
# 1                                                                               REGISTRO INICIAL RESTO DE RAZAS
# 2                                                                                 REGISTRO INICIAL GRUPO ÉTNICO
# 3                                                                                        IMPRESO ALTA DE CAMADA
# ...

# %%
df = pd.read_excel("data/2022/2022_TARIFAS_V1_Feb.xlsx")
df.head(15)
# Out:
#         Categoría  \
# 0   INSCRIPCIONES
# 1   INSCRIPCIONES
# 2   INSCRIPCIONES
# 3   INSCRIPCIONES
# 4   INSCRIPCIONES
# 5   INSCRIPCIONES
# 6   INSCRIPCIONES
# 7   INSCRIPCIONES
# 8   INSCRIPCIONES
# 9   INSCRIPCIONES
# 10  INSCRIPCIONES
# 11  INSCRIPCIONES
# 12  INSCRIPCIONES
# 13  INSCRIPCIONES
# 14  INSCRIPCIONES
#
#                                                                                                         Trámite  \
# 0                                                                              REGISTRO INICIAL RAZAS ESPAÑOLAS
# 1                                                                               REGISTRO INICIAL RESTO DE RAZAS
# 2                                                                                 REGISTRO INICIAL GRUPO ÉTNICO
# 3                                                                                        IMPRESO ALTA DE CAMADA
# ...

# %%
df = pd.read_excel("data/2022/2022_TARIFAS_V3_Oct.xlsx")
df.head(15)
# Out:
#         Categoría  \
# 0   INSCRIPCIONES
# 1   INSCRIPCIONES
# 2   INSCRIPCIONES
# 3   INSCRIPCIONES
# 4   INSCRIPCIONES
# 5   INSCRIPCIONES
# 6   INSCRIPCIONES
# 7   INSCRIPCIONES
# 8   INSCRIPCIONES
# 9   INSCRIPCIONES
# 10  INSCRIPCIONES
# 11  INSCRIPCIONES
# 12  INSCRIPCIONES
# 13  INSCRIPCIONES
# 14  INSCRIPCIONES
#
#                                                                                                         Trámite  \
# 0                                                                              REGISTRO INICIAL RAZAS ESPAÑOLAS
# 1                                                                               REGISTRO INICIAL RESTO DE RAZAS
# 2                                                                                 REGISTRO INICIAL GRUPO ÉTNICO
# 3                                                                                        IMPRESO ALTA DE CAMADA
# ...

# %% [markdown]
# 2023

# %%
df = pd.read_excel("data/2023/2023 IMPRESO COLABORADORAS V2023_1.xlsx")
df.head(15)
# Out:
#                                                                              SOCIEDAD CANINA   \
# 0                                                                                       FECHA
# 1                                                                                         NaN
# 2                                                                                    CONCEPTO
# 3                                                            INCRIPCIONES EN EL L.O.E./R.R.C.
# 4                                                         REGISTRO INICIAL DE RAZAS ESPAÑOLAS
# 5                                                         REGISTRO INICIAL DEL RESTO DE RAZAS
# 6                                                                      IMPRESO ALTA DE CAMADA
# 7                       FORMULARIO IDENTIFICACION (por cachorro al notificar nacimiento) RSCE
# 8                  FORMULARIO IDENTIFICACION (por cachorro al notificar nacimiento) EN ORIGEN
# ...

# %%
df = pd.read_excel("data/2023/2023_TARIFAS.xlsx")
df.head(15)
# Out:
#         Categoría  \
# 0   INSCRIPCIONES
# 1   INSCRIPCIONES
# 2   INSCRIPCIONES
# 3   INSCRIPCIONES
# 4   INSCRIPCIONES
# 5   INSCRIPCIONES
# 6   INSCRIPCIONES
# 7   INSCRIPCIONES
# 8   INSCRIPCIONES
# 9   INSCRIPCIONES
# 10  INSCRIPCIONES
# 11  INSCRIPCIONES
# 12  INSCRIPCIONES
# 13  INSCRIPCIONES
# 14  INSCRIPCIONES
#
#                                                                                                         Trámite  \
# 0                                                                              REGISTRO INICIAL RAZAS ESPAÑOLAS
# 1                                                                               REGISTRO INICIAL RESTO DE RAZAS
# 2                                                                                 REGISTRO INICIAL GRUPO ÉTNICO
# 3                                                                                        IMPRESO ALTA DE CAMADA
# ...

# %% [markdown]
# 2024

# %%
df = pd.read_excel("data/2024/2024 IMPRESO COLABORADORAS V3.xlsx")
df.head(15)
# Out:
#                                                                     SOCIEDAD CANINA   \
# 0                                                                              FECHA
# 1                                                                                NaN
# 2                                                                           CONCEPTO
# 3                                                   INCRIPCIONES EN EL L.O.E./R.R.C.
# 4                                                REGISTRO INICIAL DE RAZAS ESPAÑOLAS
# 5                                    REGISTRO INICIAL DE RAZAS ESPAÑOLAS VULNERABLES
# 6                                                REGISTRO INICIAL DEL RESTO DE RAZAS
# 7                                                      REGISTRO INICIAL GRUPO ÉTNICO
# 8                                                             IMPRESO ALTA DE CAMADA
# 9              FORMULARIO IDENTIFICACION (por cachorro al notificar nacimiento) RSCE
# ...

# %%
df = pd.read_excel("data/2024/2024_TARIFAS.xlsx")
df.head(15)
# Out:
#         Categoría  \
# 0   INSCRIPCIONES
# 1   INSCRIPCIONES
# 2   INSCRIPCIONES
# 3   INSCRIPCIONES
# 4   INSCRIPCIONES
# 5   INSCRIPCIONES
# 6   INSCRIPCIONES
# 7   INSCRIPCIONES
# 8   INSCRIPCIONES
# 9   INSCRIPCIONES
# 10  INSCRIPCIONES
# 11  INSCRIPCIONES
# 12  INSCRIPCIONES
# 13  INSCRIPCIONES
# 14  INSCRIPCIONES
#
#                                                                                                         Trámite  \
# 0                                                                              REGISTRO INICIAL RAZAS ESPAÑOLAS
# 1                                                                  REGISTRO INICIAL RAZAS ESPAÑOLAS VULNERABLES
# 2                                                                               REGISTRO INICIAL RESTO DE RAZAS
# 3                                                                                 REGISTRO INICIAL GRUPO ÉTNICO
# ...

# %% [markdown]
# 2025

# %%
df = pd.read_excel("data/2025/2025 IMPRESO COLABORADORAS v2.xlsx")
df.head(15)
# Out:
#                                                                     SOCIEDAD CANINA   \
# 0                                                                              FECHA
# 1                                                                                NaN
# 2                                                                           CONCEPTO
# 3                                                   INCRIPCIONES EN EL L.O.E./R.R.C.
# 4                                                REGISTRO INICIAL DE RAZAS ESPAÑOLAS
# 5                                    REGISTRO INICIAL DE RAZAS ESPAÑOLAS VULNERABLES
# 6                                                REGISTRO INICIAL DEL RESTO DE RAZAS
# 7                                                      REGISTRO INICIAL GRUPO ÉTNICO
# 8                                                             IMPRESO ALTA DE CAMADA
# 9              FORMULARIO IDENTIFICACION (por cachorro al notificar nacimiento) RSCE
# ...

# %%
df = pd.read_excel("data/2025/2025 IMPRESO COLABORADORAS v4.xlsx")
df.head(15)
# Out:
#                                                                Unnamed: 0  \
# 0                                                                     NaN
# 1                                                        SOCIEDAD CANINA
# 2                                                                   FECHA
# 3                                                                     NaN
# 4                                                                     NaN
# 5                                                                CONCEPTO
# 6                                        INCRIPCIONES EN EL L.O.E./R.R.C.
# 7                                     REGISTRO INICIAL DE RAZAS ESPAÑOLAS
# 8                         REGISTRO INICIAL DE RAZAS ESPAÑOLAS VULNERABLES
# 9                                     REGISTRO INICIAL DEL RESTO DE RAZAS
# 10                                          REGISTRO INICIAL GRUPO ÉTNICO
# 11                                                 IMPRESO ALTA DE CAMADA
# ...

# %%
df = pd.read_excel("data/2025/2025_TARIFAS_V3_Ene.xlsx")
df.head(15)
# Out:
#         Categoría  \
# 0   INSCRIPCIONES
# 1   INSCRIPCIONES
# 2   INSCRIPCIONES
# 3   INSCRIPCIONES
# 4   INSCRIPCIONES
# 5   INSCRIPCIONES
# 6   INSCRIPCIONES
# 7   INSCRIPCIONES
# 8   INSCRIPCIONES
# 9   INSCRIPCIONES
# 10  INSCRIPCIONES
# 11  INSCRIPCIONES
# 12  INSCRIPCIONES
# 13  INSCRIPCIONES
# 14  INSCRIPCIONES
#
#                                                                                                         Trámite  \
# 0                                                                              REGISTRO INICIAL RAZAS ESPAÑOLAS
# 1                                                                  REGISTRO INICIAL RAZAS ESPAÑOLAS VULNERABLES
# 2                                                                               REGISTRO INICIAL RESTO DE RAZAS
# 3                                                                                 REGISTRO INICIAL GRUPO ÉTNICO
# ...

# %%
df = pd.read_excel("data/2025/2025_TARIFAS_V4_Sept.xlsx")
df.head(15)
# Out:
#                         Categoría  \
# 0                   INSCRIPCIONES
# 1                   INSCRIPCIONES
# 2                   INSCRIPCIONES
# 3                   INSCRIPCIONES
# 4                   INSCRIPCIONES
# 5                   INSCRIPCIONES
# 6    INSCRIPCIONES ACCESS LBO/RBR
# 7    INSCRIPCIONES ACCESS LBO/RBR
# 8    INSCRIPCIONES ACCESS LBO/RBR
# 9    INSCRIPCIONES ACCESS LBO/RBR
# 10  INSCRIPCIONES PREMIUM LOE/RRC
# 11  INSCRIPCIONES PREMIUM LOE/RRC
# 12  INSCRIPCIONES PREMIUM LOE/RRC
# 13  INSCRIPCIONES PREMIUM LOE/RRC
# 14  INSCRIPCIONES PREMIUM LOE/RRC
#
#                                                                                                         Trámite  \
# 0                                                                              REGISTRO INICIAL RAZAS ESPAÑOLAS
# 1                                                                  REGISTRO INICIAL RAZAS ESPAÑOLAS VULNERABLES
# ...

# %% [markdown]
# 2026

# %%
df = pd.read_excel("data/2026/2026 IMPRESO COLABORADORAS v3.xlsx")
df.head(15)
# Out:
#                                                                Unnamed: 0  \
# 0                                                                     NaN
# 1                                                        SOCIEDAD CANINA
# 2                                                                   FECHA
# 3                  TARIFA AÑO 2026 (en vigor desde el 1 de Julio de 2026)
# 4                                                                     NaN
# 5                                                                CONCEPTO
# 6                                        INCRIPCIONES EN EL L.O.E./R.R.C.
# 7                                     REGISTRO INICIAL DE RAZAS ESPAÑOLAS
# 8                         REGISTRO INICIAL DE RAZAS ESPAÑOLAS VULNERABLES
# 9                                     REGISTRO INICIAL DEL RESTO DE RAZAS
# 10                                          REGISTRO INICIAL GRUPO ÉTNICO
# 11                                IMPRESO ALTA DE CAMADA (PERROS DE RAZA)
# ...

# %%
df = pd.read_excel("data/2026/2026 TARIFAS V2.xlsx")
df.head(15)
# Out:
#                                                                                                                             Unnamed: 0  \
# 0                                                                                                       Real Sociedad Canina de España
# 1                                                                                                                         -Desde 1911-
# 2                                                                                                            TARIFA GENERAL DE PRECIOS
# 3                                                                                         (En vigor desde el día 1 de febrero de 2026)
# 4                                                                                            El pago de los trámites podrá realizarse:
# 5   ·         Mediante transferencia bancaria o ingreso en la cuenta corriente abierta a nombre de la REAL SOCIEDAD CANINA DE ESPAÑA:
# ...
